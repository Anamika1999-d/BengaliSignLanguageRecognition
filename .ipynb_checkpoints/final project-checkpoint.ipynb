# %% [markdown]
# ## Import and Install Dependencies

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# ## Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)

        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

# %%
results.left_hand_landmarks.landmark
# Out:
# [x: 0.5400584
# y: 0.7917164
# z: 7.4850186e-07
# , x: 0.46479005
# y: 0.7856703
# z: -0.05783263
# , x: 0.4031337
# y: 0.75257796
# z: -0.088388085
# , x: 0.35749105
# y: 0.7072576
# z: -0.11259037
# , x: 0.31698012
# y: 0.655288
# z: -0.13504973
# , x: 0.44277188
# y: 0.5848617
# z: -0.0417856
# , x: 0.41485018
# y: 0.49662244
# z: -0.063155845
# , x: 0.39946425
# y: 0.4375979
# z: -0.08124924
# , x: 0.3905971
# y: 0.3896726
# z: -0.09554905
# , x: 0.48576334
# y: 0.56468475
# z: -0.033490703
# , x: 0.4730846
# y: 0.46196216
# z: -0.04904842
# , x: 0.466152
# y: 0.3972782
# z: -0.06342446
# , x: 0.46336
# y: 0.34222588
# z: -0.07557089
# , x: 0.5252392
# y: 0.56624
# z: -0.033318087
# , x: 0.5250388
# y: 0.4693818
# z: -0.054900713
# , x: 0.52348
# y: 0.40923822
# z: -0.07174443
# , x: 0.52111465
# y: 0.35237643
# z: -0.08506047
# , x: 0.56371146
# y: 0.58446
# z: -0.038827285
# , x: 0.5867356
# y: 0.52112365
# z: -0.06485439
# , x: 0.60108775
# y: 0.47822934
# z: -0.0806125
# , x: 0.6126434
# y: 0.43373123
# z: -0.09174076
# ]

# %% [markdown]
# ## Extract Keypoint Values

# %%
def extract_keypoints(results):
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([lh, rh])

# %% [markdown]
# ## Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['A', 'Aa', 'I','U','E','O','Ka','Kha','Ga','Gha','Ca','Cha',
                    'Ja','Jha','Tta','Ttha','Dda','Ddha','Ta','Tha','Da','Dha','Na','Pa',
                    'Pha','Ba','Bha','Ma','Ya','Ra','La','Sa','Ha','Rra','Sign1','Sign2'
                   ])
Sign=np.array(['অ','আ','ই','উ','এ','ও','ক','খ','গ','ঘ','চ','ছ',
               'জ','ঝ','ট','ঠ','ড','ঢ','ত','থ','দ','ধ','ন','প',
               'ফ','ব','ভ','ম','য','র','ল','স','হ','ড়','ং','ঃ',
              ])

# Thirty videos worth of data
no_sequences = 40

# Videos are going to be 30 frames in length
sequence_length = 50

# %%
for action in actions: 
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# ##  Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        # Loop through sequences aka videos
        for sequence in range(no_sequences):
            # Loop through video length aka sequence length
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Make detections
                image, results = mediapipe_detection(frame, holistic)
#                 print(results)

                # Draw landmarks
                draw_styled_landmarks(image, results)
                
                # NEW Apply wait logic
                if frame_num == 0: 
                    cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                               cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(2000)
                else: 
                    cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    # Show to screen
                    cv2.imshow('OpenCV Feed', image)
                
                # NEW Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                np.save(npy_path, keypoints)

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break
                    
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ## 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'A': 0,
#  'Aa': 1,
#  'I': 2,
#  'U': 3,
#  'E': 4,
#  'O': 5,
#  'Ka': 6,
#  'Kha': 7,
#  'Ga': 8,
#  'Gha': 9,
#  'Ca': 10,
#  'Cha': 11,
#  'Ja': 12,
#  'Jha': 13,
#  'Tta': 14,
#  'Ttha': 15,
#  'Dda': 16,
#  'Ddha': 17,
#  'Ta': 18,
#  'Tha': 19,
#  'Da': 20,
#  'Dha': 21,
#  'Na': 22,
#  'Pa': 23,
#  'Pha': 24,
#  'Ba': 25,
#  'Bha': 26,
#  'Ma': 27,
#  'Ya': 28,
#  'Ra': 29,
#  'La': 30,
#  'Sa': 31,
#  'Ha': 32,
#  'Rra': 33,
#  'Sign1': 34,
#  'Sign2': 35}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in range(no_sequences):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (1440, 50, 126)

# %%
np.array(labels).shape
# Out:
# (1440,)

# %%
X = np.array(sequences)
y = to_categorical(labels).astype(int)

# %%
X.shape
# Out:
# (1440, 50, 126)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_train.shape
# Out:
# (1368, 36)

# %% [markdown]
# ##  Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(50,126)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, callbacks=[tb_callback])
# Out:
# Epoch 1/100
# 43/43 [==============================] - 7s 92ms/step - loss: 3.5824 - categorical_accuracy: 0.0264
# Epoch 2/100
# 43/43 [==============================] - 2s 56ms/step - loss: 3.8065 - categorical_accuracy: 0.0363
# Epoch 3/100
# 43/43 [==============================] - 2s 56ms/step - loss: 3.5845 - categorical_accuracy: 0.0301
# Epoch 4/100
# 43/43 [==============================] - 2s 57ms/step - loss: 3.6107 - categorical_accuracy: 0.0513
# Epoch 5/100
# 43/43 [==============================] - 2s 57ms/step - loss: 3.5750 - categorical_accuracy: 0.0367
# Epoch 6/100
# 43/43 [==============================] - 3s 59ms/step - loss: 3.8468 - categorical_accuracy: 0.0641
# Epoch 7/100
# 43/43 [==============================] - 2s 54ms/step - loss: 3.5424 - categorical_accuracy: 0.0297
# Epoch 8/100
# 43/43 [==============================] - 3s 59ms/step - loss: 3.4164 - categorical_accuracy: 0.0412
# Epoch 9/100
# 43/43 [==============================] - 3s 59ms/step - loss: 3.4687 - categorical_accuracy: 0.0645
# Epoch 10/100
# 43/43 [==============================] - 3s 58ms/step - loss: 3.7577 - categorical_accuracy: 0.0903
# Epoch 11/100
# 43/43 [==============================] - 3s 60ms/step - loss: 3.5877 - categorical_accuracy: 0.0301
# Epoch 12/100
# 43/43 [==============================] - 3s 62ms/step - loss: 3.5450 - categorical_accuracy: 0.0372
# Epoch 13/100
# 43/43 [==============================] - 3s 59ms/step - loss: 3.4822 - categorical_accuracy: 0.0712
# Epoch 14/100
# 43/43 [==============================] - 3s 61ms/step - loss: 3.3126 - categorical_accuracy: 0.0573
# Epoch 15/100
# 43/43 [==============================] - 3s 62ms/step - loss: 3.2641 - categorical_accuracy: 0.0795
# Epoch 16/100
# 43/43 [==============================] - 3s 61ms/step - loss: 3.2182 - categorical_accuracy: 0.1149
# Epoch 17/100
# 43/43 [==============================] - 3s 64ms/step - loss: 3.0772 - categorical_accuracy: 0.1325
# Epoch 18/100
# 43/43 [==============================] - 3s 61ms/step - loss: 3.1458 - categorical_accuracy: 0.0720
# Epoch 19/100
# 43/43 [==============================] - 3s 71ms/step - loss: 2.7382 - categorical_accuracy: 0.1712
# Epoch 20/100
# 43/43 [==============================] - 3s 64ms/step - loss: 2.6480 - categorical_accuracy: 0.1706
# Epoch 21/100
# 43/43 [==============================] - 3s 69ms/step - loss: 2.4738 - categorical_accuracy: 0.2110
# Epoch 22/100
# 43/43 [==============================] - 3s 67ms/step - loss: 2.2939 - categorical_accuracy: 0.2613
# Epoch 23/100
# 43/43 [==============================] - 3s 66ms/step - loss: 2.2712 - categorical_accuracy: 0.2844
# Epoch 24/100
# 43/43 [==============================] - 3s 80ms/step - loss: 2.6884 - categorical_accuracy: 0.2189 0s - loss: 2.7201 - categorical_
# Epoch 25/100
# 43/43 [==============================] - 4s 88ms/step - loss: 2.1671 - categorical_accuracy: 0.3333
# Epoch 26/100
# 43/43 [==============================] - 4s 83ms/step - loss: 2.8633 - categorical_accuracy: 0.1429
# Epoch 80/100
# 43/43 [==============================] - 3s 79ms/step - loss: 2.7466 - categorical_accuracy: 0.1375
# Epoch 81/100
# 43/43 [==============================] - 3s 79ms/step - loss: 3.3662 - categorical_accuracy: 0.0747
# Epoch 82/100
# 43/43 [==============================] - 4s 84ms/step - loss: 2.8868 - categorical_accuracy: 0.1266
# Epoch 83/100
# 43/43 [==============================] - 4s 83ms/step - loss: 2.6622 - categorical_accuracy: 0.1501
# Epoch 84/100
# 43/43 [==============================] - 3s 81ms/step - loss: 2.6099 - categorical_accuracy: 0.1918
# Epoch 85/100
# 43/43 [==============================] - 4s 85ms/step - loss: 2.5074 - categorical_accuracy: 0.2248
# Epoch 86/100
# 43/43 [==============================] - 4s 83ms/step - loss: 2.4810 - categorical_accuracy: 0.2443
# Epoch 87/100
# 43/43 [==============================] - 4s 85ms/step - loss: 2.3235 - categorical_accuracy: 0.2882
# Epoch 88/100
# 43/43 [==============================] - 3s 81ms/step - loss: 2.3380 - categorical_accuracy: 0.2594
# Epoch 89/100
# 43/43 [==============================] - 4s 83ms/step - loss: 2.2687 - categorical_accuracy: 0.2917
# Epoch 90/100
# 43/43 [==============================] - 3s 80ms/step - loss: 2.0727 - categorical_accuracy: 0.3739
# Epoch 91/100
# 43/43 [==============================] - 4s 82ms/step - loss: 2.2272 - categorical_accuracy: 0.3332
# Epoch 92/100
# 43/43 [==============================] - 4s 84ms/step - loss: 2.2548 - categorical_accuracy: 0.2831
# Epoch 93/100
# 43/43 [==============================] - 4s 82ms/step - loss: 1.9785 - categorical_accuracy: 0.4009
# Epoch 94/100
# 43/43 [==============================] - 3s 81ms/step - loss: 3.3562 - categorical_accuracy: 0.3924
# Epoch 95/100
# 43/43 [==============================] - 3s 78ms/step - loss: 1.9235 - categorical_accuracy: 0.3967
# Epoch 96/100
# 43/43 [==============================] - 3s 80ms/step - loss: 1.8379 - categorical_accuracy: 0.4299
# Epoch 97/100
# 43/43 [==============================] - 4s 83ms/step - loss: 1.7276 - categorical_accuracy: 0.4765
# Epoch 98/100
# 43/43 [==============================] - 3s 76ms/step - loss: 1.6018 - categorical_accuracy: 0.5115
# Epoch 99/100
# 43/43 [==============================] - 3s 78ms/step - loss: 1.5750 - categorical_accuracy: 0.5042
# Epoch 100/100
# 43/43 [==============================] - 3s 80ms/step - loss: 1.6104 - categorical_accuracy: 0.4986

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50, 64)            48896
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50, 128)           98816
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 36)                1188
# =================================================================
# Total params: 204,548
# Trainable params: 204,548
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[14])]
# Out:
# 'Ttha'

# %%
actions[np.argmax(y_test[14])]
# Out:
# 'U'

# %% [markdown]
# ## Save Weights

# %%
model.save('action.h5')

# %%
model.load_weights('action.h5')

# %% [markdown]
# ## Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score,classification_report

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(model, ytrue, yhat)  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-13e59b5eb223> in <module>
#       1 import matplotlib.pyplot as plt
#       2 from sklearn.metrics import plot_confusion_matrix
# ----> 3 plot_confusion_matrix(model, ytrue, yhat)
#       4 plt.show()
#
# c:\python\python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\python\python39\lib\site-packages\sklearn\metrics\_plot\confusion_matrix.py in plot_confusion_matrix(estimator, X, y_true, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax, colorbar)
#     256
#     257     if not is_classifier(estimator):
# --> 258         raise ValueError("plot_confusion_matrix only supports classifiers")
#     259
#     260     y_pred = estimator.predict(X)
#
# ValueError: plot_confusion_matrix only supports classifiers

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[70,  0],
#         [ 2,  0]],
#
#        [[67,  2],
#         [ 2,  1]],
#
#        [[65,  4],
#         [ 2,  1]],
#
#        [[68,  1],
#         [ 3,  0]],
#
#        [[69,  0],
#         [ 0,  3]],
#
#        [[71,  0],
#         [ 1,  0]],
#
#        [[69,  0],
#         [ 1,  2]],
#
#        [[69,  2],
#         [ 0,  1]],
#
#        [[69,  0],
#         [ 0,  3]],
#
#        [[71,  0],
#         [ 0,  1]],
#
#        [[69,  0],
#         [ 0,  3]],
#
#        [[69,  0],
#         [ 0,  3]],
#
#        [[69,  3],
#         [ 0,  0]],
#
#        [[69,  2],
#         [ 0,  1]],
#
#        [[67,  2],
#         [ 3,  0]],
#
#        [[70,  0],
#         [ 1,  1]],
#
#        [[71,  1],
#         [ 0,  0]],
#
#        [[69,  0],
#         [ 0,  3]],
#
#        [[71,  0],
#         [ 0,  1]],
#
#        [[68,  2],
#         [ 0,  2]],
#
#        [[68,  2],
#         [ 0,  2]],
#
#        [[69,  1],
#         [ 2,  0]],
#
#        [[70,  0],
#         [ 1,  1]],
#
#        [[69,  1],
#         [ 1,  1]],
#
#        [[66,  5],
#         [ 0,  1]],
#
#        [[71,  0],
#         [ 1,  0]],
#
#        [[69,  0],
#         [ 2,  1]],
#
#        [[68,  0],
#         [ 4,  0]],
#
#        [[69,  0],
#         [ 0,  3]],
#
#        [[66,  3],
#         [ 1,  2]],
#
#        [[71,  0],
#         [ 1,  0]],
#
#        [[69,  1],
#         [ 0,  2]],
#
#        [[70,  0],
#         [ 2,  0]],
#
#        [[69,  0],
#         [ 2,  1]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.5555555555555556

# %% [markdown]
#  ## Test in Real Time

# %%
# 1. New detection variables
sequence = []
sentence = []
threshold = 0.4

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.insert(0,keypoints)
        sequence = sequence[:30]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(Sign[np.argmax(res)])
                        
            
        #3. Viz logic
        if res[np.argmax(res)] > threshold: 
            if len(sentence) > 0: 
                if actions[np.argmax(res)] != sentence[-1]:
                    sentence.append(actions[np.argmax(res)])
            else:
                sentence.append(actions[np.argmax(res)])

        if len(sentence) > 5: 
            sentence = sentence[-5:]
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ং
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ং
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ং
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ই
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ই
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ম
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ট
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ট
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ক
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ট
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ট
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ট
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ট
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ট
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ট
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ট
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ট
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ং
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ং
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ং
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# এ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# এ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# এ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# এ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# এ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# এ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# এ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# খ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# খ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# খ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# খ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# খ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ড
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ও
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# থ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# চ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# চ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# চ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# চ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# চ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# চ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# চ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# চ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ল
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঃ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ম
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ম
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ম
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ম
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ম
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ম
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ম
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ম
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# উ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ও
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ও
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ও
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# স
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ব
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ছ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ও
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ও
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ও
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# য
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# হ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঢ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# ঘ
